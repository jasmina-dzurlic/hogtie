# %% [markdown]
# ## Python challenges
#
# This notebook includes a series of challenges to test your Python coding skills. If you get stuck, try googling for answers. If you don't understand *why* a particular answer works, try searching for the answer to that question. Revisit old tutorials from this class as needed, and finally, turn to the course chatroom for help. Best of luck.

# %%
# required software
# conda install numpy pandas toyplot requests -c conda-forge

# %%
import requests
import numpy as np
import pandas as pd
import toyplot

# %% [markdown]
# ### Challenge 1:
# Execute the code cell below to see an example of how it works.
# Use markdown in the cell after the code-block to describe the function `random_words_api`. Try to be descriptive about what each step of code in this function does, and why it works.

# %%
def random_words_api(nwords=10):
    "no docstring"
    URL = "https://random-word-api.herokuapp.com/word"
    response = requests.get(url=URL, params={"number": nwords})
    return response.json()

# demonstration
random_words_api(5)
# Out:
# ['charladies', 'gallonages', 'penuchi', 'pearlescences', 'misshape']

# %% [markdown]
# **Description:**
# This function queries a random words app that's hosted through heroku to get a certain number of random words.

# %% [markdown]
# ### Challenge 2:
# Use the `random_words_api` function to get 50 random words and store the result as a variable. Write a function that takes the list of words as input and returns a dictionary with the longest word as the key and the length of the longest word as a value. If there is a tie in the length of words then have it return additional words as keys with their lengths as values.

# %%
mywords = random_words_api(nwords=50)
def longest_word(words):
    long = max(words, key=len)
    keys = []
    values = []
    for word in words:
        if len(word) == len(long):
            keys.append(word)
            values.append(len(word))
    return dict(zip(keys, values))

# %%
longest_word(words = mywords)
# Out:
# {'irreducibility': 14, 'zoogeographers': 14, 'foodlessnesses': 14}

# %% [markdown]
# ### Challenge 3:
# Write a function to take the list of words as input and trim all words to be at most 5 characters in length, and return as a list.

# %%
def wordtrim(words):
    fives = []
    for word in words:
        short = word[:5]
        fives.append(short)
    return fives

# %%
#wordtrim(words = mywords)

# %% [markdown]
# ### Challenge 4:
# Write a function to take a list of words as input and to count the occurrence of all letters in every word and return as a dictionary mapping letters to integers., e.g., {'a': 10, 'b': 3, 'c': 5, ...}.

# %%
def lettercount(words):
    counts={}
    for word in words:
        for letter in word:
            keys=counts.keys()
            if letter in keys:
                counts[letter]+=1
            else:
                counts[letter]=1
    return counts

# %%
worddict = lettercount(words = mywords)
worddict
# Out:
# {'u': 18,
#  'n': 31,
#  'd': 19,
#  'e': 53,
#  'r': 32,
#  'b': 8,
#  'o': 25,
#  'i': 35,
#  's': 40,
#  't': 24,
#  'h': 12,
#  'a': 34,
#  'g': 8,
#  'p': 16,
#  'c': 13,
#  'w': 3,
#  'm': 10,
#  'l': 27,
#  'y': 5,
#  'f': 9,
#  'x': 3,
#  'z': 3,
#  'k': 7,
#  'j': 4,
#  'v': 3}

# %% [markdown]
# ### Challenge 5:
# Use [toyplot](https://toyplot.readthedocs.io/en/stable/tutorial.html) to create a barplot of the occurrences of each letter in your dictionary from the previous challenge. This will represent a histogram of the letters. Play with the size and color of the figure to try to make it look nice.

# %%
keys = list(worddict.keys())
edges = np.array(keys)
values = list(worddict.values())
hist = np.array(values)
toyplot.bars(
    (hist, edges), 
    height=200, 
    width=400,
);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/miniconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/miniconda3/lib/python3.8/site-packages/toyplot/canvas.py in _repr_html_(self)
#     226     def _repr_html_(self):
#     227         from . import html
# --> 228         return toyplot.html.tostring(self, style={"text-align":"center"})
#     229
#     230     def _repr_png_(self):
#
# ~/miniconda3/lib/python3.8/site-packages/toyplot/html.py in tostring(canvas, style)
#     371     <body> etc. if the result is intended as a standalone HTML document.
#     372     """
# --> 373     return xml.tostring(render(canvas=canvas, style=style), encoding="unicode", method="html")
#     374
#     375
#
# ~/miniconda3/lib/python3.8/site-packages/toyplot/html.py in render(canvas, fobj, animation, style)
#     331
#     332     # Render the canvas.
# --> 333     _render(canvas, context.copy(parent=root_xml)) # pylint: disable=no-value-for-parameter
#     334
#     335     # Return / write the results.
#
# ~/miniconda3/lib/python3.8/site-packages/multipledispatch/dispatcher.py in __call__(self, *args, **kwargs)
#     276             self._cache[types] = func
#     277         try:
# --> 278             return func(*args, **kwargs)
#     279
#     280         except MDNotImplementedError:
#
# ~/miniconda3/lib/python3.8/site-packages/toyplot/html.py in _render(canvas, context)
#     803     # Render everything on the canvas.
#     804     for node in context.scenegraph.targets(canvas, "render"):
# --> 805         _render(node._finalize(), context.copy(parent=svg_xml))
#     806
#     807     # Create a container for any Javascript code.
#
# ~/miniconda3/lib/python3.8/site-packages/toyplot/coordinates.py in _finalize(self)
#     808                 child = child._finalize()
#     809                 if child is not None:
# --> 810                     self.x._update_domain(child.domain("x"), display=True, data=not child.annotation)
#     811
#     812                     (x, y), (left, right, top, bottom) = child.extents(["x", "y"])
#
# ~/miniconda3/lib/python3.8/site-packages/toyplot/mark.py in domain(self, axis)
#     258     def domain(self, axis):
#     259         if axis == self._coordinate_axes[0]:
# --> 260             return toyplot.data.minimax([self._table[self._left[0]], self._table[self._right[0]]])
#     261         if axis == self._coordinate_axes[1]:
#     262             boundaries = numpy.column_stack([self._table[key] for key in self._magnitudes])
#
# ~/miniconda3/lib/python3.8/site-packages/toyplot/data.py in minimax(items)
#      56         selection = numpy.logical_not(selection)
#      57         if numpy.count_nonzero(selection):
# ---> 58             item_min = item[selection].min()
#      59             item_max = item[selection].max()
#      60
#
# ~/miniconda3/lib/python3.8/site-packages/numpy/ma/core.py in min(self, axis, out, fill_value, keepdims)
#    5694         # No explicit output
#    5695         if out is None:
# -> 5696             result = self.filled(fill_value).min(
#    5697                 axis=axis, out=out, **kwargs).view(type(self))
#    5698             if result.ndim:
#
# ~/miniconda3/lib/python3.8/site-packages/numpy/core/_methods.py in _amin(a, axis, out, keepdims, initial, where)
#      41 def _amin(a, axis=None, out=None, keepdims=False,
#      42           initial=_NoValue, where=True):
# ---> 43     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#      44
#      45 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: cannot perform reduce with flexible type

# %%
dict2 = {1:3, 2:4, 3:5, 4:4, 5:3}
keys = list(dict2.keys())
keys = np.array(keys)
values = list(dict2.values())
valus = np.array(values)

#toyplot.bars(
#    (keys, values), 
#    height=200, 
#    width=400,
#    color="orange"
#);
# Out:
# 5

# %% [markdown]
# ### Challenge 6:
# Using numpy create a new variable called `arr` with 1000 random samples from a normal distribution. Use the numpy `.histogram` function to bin these values into 20 bins, and then plot the histogram using a barplot from toyplot. Color the bars of the histogram orange.

# %%
arr = np.random.normal(loc = 0, scale = 2.0, size = 1000)
hist, edges = np.histogram(arr, bins=20, density=True)
toyplot.bars(
    (hist, edges), 
    height=200, 
    width=400,
    color="orange"
);
len(edges)
# Out:
# 21
# <div class="toyplot" id="te1d3a789a6e44bde91e1e301f2c57ea1" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="400.0px" height="200.0px" viewBox="0 0 400.0 200.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t0b017c67c0f74011900cdf09308fd380"><g class="toyplot-coordinates-Cartesian" id="te9ab16bd88ce48f7b12ddee21c4ac326"><clipPath id="t6b71bfcef193425f88e2d90eb4f563a1"><rect x="40.0" y="40.0" width="320.0" height="120.0"></rect></clipPath><g clip-path="url(#t6b71bfcef193425f88e2d90eb4f563a1)"><g class="toyplot-mark-BarMagnitudes" style="stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" id="t0ef33bf1ba374c438b4b64c36ca539a3"><g class="toyplot-Series"><rect class="toyplot-Datum" x="50.0" y="148.3210575833541" width="14.999999999999986" height="1.6789424166458957" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"></rect><rect class="toyplot-Datum" x="64.99999999999999" y="144.12370154173928" width="15.000000000000014" height="5.87629845826072" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"></rect><rect class="toyplot-Datum" x="80.0" y="134.88951825018668" width="15.0" height="15.110481749813317" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"></rect><rect class="toyplot-Datum" x="95.0" y="121.4579789170193" width="15.0" height="28.542021082980696" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"></rect><rect class="toyplot-Datum" x="110.0" y="116.42115166708155" width="15.0" height="33.578848332918454" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"></rect><rect class="toyplot-Datum" x="125.0" y="98.79225629229931" width="15.0" height="51.207743707700686" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"></rect><rect class="toyplot-Datum" x="140.0" y="77.80547608422538" width="15.0" height="72.19452391577462" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"></rect><rect class="toyplot-Datum" x="155.0" y="59.337109501120096" width="15.0" height="90.6628904988799" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"></rect><rect class="toyplot-Datum" x="170.0" y="61.855523126088976" width="14.999999999999972" height="88.14447687391103" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"></rect><rect class="toyplot-Datum" x="184.99999999999997" y="50.10292620956765" width="15.000000000000028" height="99.89707379043236" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"></rect><rect class="toyplot-Datum" x="200.0" y="53.46081104285935" width="14.999999999999972" height="96.53918895714065" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"></rect><rect class="toyplot-Datum" x="214.99999999999997" y="79.48441850087117" width="15.000000000000028" height="70.51558149912883" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"></rect><rect class="toyplot-Datum" x="230.0" y= ...

# %% [markdown]
# ### Challenge 7:
# Write a `while` statement to continue running code in a loop until a condition is met, and then call `break` to end the loop. Inside of the loop, randomly draw a single value from a uniform distribution between 0 and 100. If the value is less than 25 and greater than 22 then break the loop, otherwise, continue the loop until a value meeting this condition is sampled. Use a variable to keep track of how many iterations of the loop are run, and print this value after calling `break`.

# %%
loops = 0
while np.random.uniform(0,100,1):
    loops += 1
    if 22 < np.random.uniform(0,100,1) < 25:
        break
print("The number of loops run was " + str(loops))
# Out:
# The number of loops run was 44

# %% [markdown]
# ### Challenge 8:
# Use pandas to load a CSV file from https://eaton-lab.org/data/iris-data-dirty.csv and save as a dataframe. Add custom names to the columns in the dataframe, based on the type of values in them (e.g., numeric versus strings). You can come up with any column names you want for these.

# %%
data = pd.read_csv(
    "http://eaton-lab.org/data/iris-data-dirty.csv", 
    header=None) 
data.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
data.columns=["leaf_len", "root_len", "style_len", "pistil_len", "species"]
data.head()
# Out:
#    leaf_len  root_len  style_len  pistil_len      species
# 0       5.1       3.5        1.4         0.2  Iris-setosa
# 1       4.9       3.0        1.4         0.2  Iris-setosa
# 2       4.7       3.2        1.3         0.2  Iris-setosa
# 3       4.6       3.1        1.5         0.2  Iris-setosa
# 4       5.0       3.6        1.4         0.2  Iris-setosa

# %% [markdown]
# ### Challenge 9:
# Calculate the mean value of the data in the left-most column for all data where the right-most column matches the value "Iris-setosa".

# %%
setosa = data.query('species == "Iris-setosa"')
setosa['leaf_len'].mean(axis = 0)
# Out:
# 5.010204081632653

# %% [markdown]
# ### Challenge 10:
# Create a copy of your iris data dataframe and name it `df2`. Sort the rows of this dataframe based on the values in the first (leftmost) column so that the lowest values are first, and the highest values at the bottom. After sorting, reset the index of the dataframe so that the index is once again ordered. Once you get this to work, try to rewrite it in a simpler form by chaining multiple function calls together to accomplish the goal in one line, by calling code that looks a bit like this, but with the correct function calls: `df.function().function().function()`

# %%
df2 = data.copy()
df2 = df2.sort_values(by='leaf_len',axis=0)
df2 = df2.reset_index()
df2.drop(labels="index", axis=1)
# Out:
#      leaf_len  root_len  style_len  pistil_len         species
# 0         4.3       3.0        1.1         0.1     Iris-setosa
# 1         4.4       3.2        1.3         0.2     Iris-setosa
# 2         4.4       3.0        1.3         0.2     Iris-setosa
# 3         4.4       2.9        1.4         0.2     Iris-setosa
# 4         4.5       2.3        1.3         0.3     Iris-setosa
# ..        ...       ...        ...         ...             ...
# 145       7.7       2.8        6.7         2.0  Iris-virginica
# 146       7.7       2.6        6.9         2.3  Iris-virginica
# 147       7.7       3.8        6.7         2.2  Iris-virginica
# 148       7.7       3.0        6.1         2.3  Iris-virginica
# 149       7.9       3.8        6.4         2.0  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df2.sort_values(by='leaf_len',axis=0).drop(labels="index", axis=1)
# Out:
#      leaf_len  root_len  style_len  pistil_len         species
# 0         4.3       3.0        1.1         0.1     Iris-setosa
# 1         4.4       3.2        1.3         0.2     Iris-setosa
# 2         4.4       3.0        1.3         0.2     Iris-setosa
# 3         4.4       2.9        1.4         0.2     Iris-setosa
# 4         4.5       2.3        1.3         0.3     Iris-setosa
# ..        ...       ...        ...         ...             ...
# 147       7.7       3.8        6.7         2.2  Iris-virginica
# 148       7.7       3.0        6.1         2.3  Iris-virginica
# 145       7.7       2.8        6.7         2.0  Iris-virginica
# 146       7.7       2.6        6.9         2.3  Iris-virginica
# 149       7.9       3.8        6.4         2.0  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Challenge 11:
# Write a function that uses string formatting (curly braces) to create a [mad lib](https://en.wikipedia.org/wiki/Mad_Libs) containing at least 4 words that will be filled in. The returned object of your function should be a string where the missing words are filled by randomly sampled words from the `random_words_api()` function. The sentence or paragraph of your mad lib can be anything you wish, be creative.

# %%
def madlibs():
    word1 = random_words_api(1)[0]
    word2 = random_words_api(1)[0]
    word3 = random_words_api(1)[0]
    word4 = random_words_api(1)[0]
    word5 = random_words_api(1)[0]
    print(f"Once upon a time there was a {word1}. " +
          f"That {word1} had a dream of eating all of the {word2} in the world. "+ 
          f"One day, the {word1} walked into a diner called THE {word3.upper()} and yelled, "+
          f"'Hello! I have come to eat all of your {word2}!' "+
          f"The owner looked at the {word1} and said, "+
          f"'You must be {word4} if you think we will allow you to eat all of our {word2}! You are much too {word5}. '"+
          f"The {word1} burst into tears and ran out of THE {word3.upper()} as fast as he could, never to be seen again.")

# %%
madlibs()
# Out:
# Once upon a time there was a crepitate. That crepitate had a dream of eating all of the understaffings in the world. One day, the crepitate walked into a diner called THE ENDOLYMPH and yelled, 'Hello! I have come to eat all of your understaffings!' The owner looked at the crepitate and said, 'You must be adeemed if you think we will allow you to eat all of our understaffings! You are much too nonattendances. 'The crepitate burst into tears and ran out of THE ENDOLYMPH as fast as he could, never to be seen again.

# %% [markdown]
# <div class="alert alert-success">
# After completing all challenges in this notebook, save and download the .ipynb file to your computer. Move the file to your hack-program repo and put it in a folder called notebooks. Add/stage this file and folder and commit the change, and push to GitHub. The assignment is due by end of day on 3/7/2021.
# </div>
